# %%
import pandas as pd,numpy as np,os,glob,spacy
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
  
ps = PorterStemmer()

# %%
import pandas as pd
df=pd.read_csv('d2.csv')
save=[]
for x1,x2 in enumerate(df['text']):
#     print(x2)
    if x1==df.shape[0]-5:
        break
    c=0
#     print(x2.count('.'))
    if x2.count('.')>=3:
        save.append(x1)

# %%
df=pd.read_csv('project_test.csv')
import nltk

sen_idx=[]
vocab=[]
absindx=[]
k=0
for i1 in range(df.shape[0]):
    
    abs_idx=nltk.word_tokenize(df['text'][i1])
    abstract=[i1 for i5 in range(len(abs_idx))]
    absindx+=abstract
    tokens = nltk.sent_tokenize(df['text'][i1])

   
    for ix,t in enumerate(tokens):
        print(len(nltk.word_tokenize(t)))
        print('sentence no.',k)
        word=[i4 for i4 in nltk.word_tokenize(t)]
        vocab+=word
        w_idx=[k for i2 in range(len(nltk.word_tokenize(t)))]
        sen_idx+=w_idx
        k+=1
# Out:
# 35
# sentence no. 0
# 34
# sentence no. 1
# 25
# sentence no. 2
# 45
# sentence no. 3
# 28
# sentence no. 4
# 30
# sentence no. 5
# 61
# sentence no. 6
# 41
# sentence no. 7
# 25
# sentence no. 8
# 27
# sentence no. 9
# 20
# sentence no. 10
# 24
# sentence no. 11
# 29
# sentence no. 12
# 21
# sentence no. 13
# 33
# sentence no. 14
# 30
# sentence no. 15
# 21
# sentence no. 16
# 40
# sentence no. 17
# 19
# sentence no. 18
# 16
# sentence no. 19
# 13
# sentence no. 20
# 23
# sentence no. 21
# 18
# sentence no. 22
# 23
# sentence no. 23
# 16
# sentence no. 24
# 34
# sentence no. 25
# 15
# sentence no. 26
# 33
# sentence no. 27
# 21
# sentence no. 28
# 19
# sentence no. 29
# 32
# sentence no. 30
# 17
# sentence no. 31
# 32
# sentence no. 32
# 10
# sentence no. 33
# 40
# sentence no. 34
# 21
# sentence no. 35
# 16
# sentence no. 36
# 23
# sentence no. 37
# 21
# sentence no. 38
# 13
# sentence no. 39
# 23
# sentence no. 40
# 39
# sentence no. 41
# 30
# sentence no. 42
# 31
# ...

# %%
df2=pd.DataFrame(columns=['text','sentence_idx','abstract_idx'])

df2['text']=vocab
df2['sentence_idx']=sen_idx
df2['abstract_idx']=absindx
df2.head(5)
# Out:
#           text  sentence_idx  abstract_idx
# 0            A             0             0
# 1       series             0             0
# 2           of             0             0
# 3  naphthalene             0             0
# 4      diimide             0             0

# %%
for x1,x2 in enumerate(df2['text']):
    df2['text'][x1]=ps.stem(x2)
# Out:
# /tmp/ipykernel_4528/920576074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['text'][x1]=ps.stem(x2)

# %% [markdown]
# ## labeling

# %%
names=['added','fabricate','synthesized','prepared','produced','process','synthesize','improve','manufactured']
names2=[ps.stem(i) for i in names]

print(names2)

label_p=[i1 for i1,i2 in enumerate(df2['text']) if '3' in i2 and len(i2)>=4 or 'pero' in i2 or 'PSC' in i2]
len(label_p)

label_m=[i1 for i1,i2 in enumerate(df2['text']) if ps.stem(i2) in names2]

for a1,a2 in enumerate(df2['text']):
    if a1 in label_p:
        df2.loc[a1,'label']='B'
    elif a1 in label_m:
        df2.loc[a1,'label']='I'
    else: df2.loc[a1,'label']='O'
# Out:
# ['ad', 'fabric', 'synthes', 'prepar', 'produc', 'process', 'synthes', 'improv', 'manufactur']

# %%
df2.tail(10)
# Out:
#             text  sentence_idx  abstract_idx label
# 35115  perovskit          1192           200     B
# 35116      solar          1192           200     O
# 35117       cell          1192           200     O
# 35118       with          1192           200     O
# 35119       high          1192           200     O
# 35120     effici          1192           200     O
# 35121        and          1192           200     O
# 35122       good          1192           200     O
# 35123     stabil          1192           200     O
# 35124          .          1192           200     O

# %%
df2.to_csv('df2.csv',index=False)

# %%
import csv
with open('df2.csv','r') as csvin, open('test.tsv', 'w') as tsvout:
    csvin = csv.reader(csvin)
    tsvout = csv.writer(tsvout, delimiter='\t')

    for row in csvin:
        tsvout.writerow(row)

# %%
import os
os.getcwd()
# Out:
# '/home/sourin/nlp_project/Campaign_Text_Classification/Data'
